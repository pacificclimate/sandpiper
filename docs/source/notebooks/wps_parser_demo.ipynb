# %% [markdown]
# ## Parser
# Takes a logical condition and parses it into a parse tree. Returns a tuple:
# - Parse tree
# - Variables used in the parse tree
# - Region

# %%
from birdy import WPSClient
from pkg_resources import resource_filename
import os

# Ensure we are in the working directory with access to the data
if os.path.basename(os.getcwd()) != "sandpiper":
    os.chdir('../../../')

url = 'https://docker-dev03.pcic.uvic.ca/twitcher/ows/proxy/sandpiper/wps'
sandpiper = WPSClient(url)

# %% [markdown]
# The list of available processes can be diplayed using the `?` command (ex. `bird?`). Furthermore, help for individual processes can be diplayed using the same command (ex. `bird.process?`).

# %%
# NBVAL_IGNORE_OUTPUT
sandpiper.parser?
# Out:
# Signature: sandpiper.parser(condition, loglevel='INFO')
# Docstring:
# Process a condition into a parse tree
#
# Parameters
# ----------
# condition : string
#     The condition used to break down
# loglevel : {'CRITICAL', 'ERROR', 'WARNING', 'INFO', 'DEBUG', 'NOTSET'}string
#     Logging level
#
# Returns
# -------
# parse_tree : string
#     Parse tree generated by a condition
# variables : string
#     All variables used in the parse tree
# region_variable : string
#     The region the data is associated with
# File:      ~/code/birds/sandpiper/</tmp/sandpiper-venv/lib/python3.8/site-packages/birdy/client/base.py-1>
# Type:      method

# %% [markdown]
# sandpiper.parser expects the condition as a string.

# %%
condition = "((temp_djf_iamean_s0p_hist <= -6) && (temp_djf_iamean_s100p_hist >= -6)) || ((temp_djf_iamean_s0p_hist <= 5) && (temp_djf_iamean_s100p_hist >= 5)) || ((temp_djf_iamean_s0p_hist >= -6) && (temp_djf_iamean_s100p_hist <= 5))"
output = sandpiper.parser(condition=condition)

for value in output.get():
    print(value)
# Out:
# ('||', ('||', ('&&', ('<=', 'temp_djf_iamean_s0p_hist', -6.0), ('>=', 'temp_djf_iamean_s100p_hist', -6.0)), ('&&', ('<=', 'temp_djf_iamean_s0p_hist', 5.0), ('>=', 'temp_djf_iamean_s100p_hist', 5.0))), ('&&', ('>=', 'temp_djf_iamean_s0p_hist', -6.0), ('<=', 'temp_djf_iamean_s100p_hist', 5.0)))
# {'temp_djf_iamean_s0p_hist': {'variable': 'temp', 'time_of_year': 'djf', 'temporal': 'iamean', 'spatial': 's0p', 'percentile': 'hist'}, 'temp_djf_iamean_s100p_hist': {'variable': 'temp', 'time_of_year': 'djf', 'temporal': 'iamean', 'spatial': 's100p', 'percentile': 'hist'}}
# None

# %% [markdown]
# Now that we've run the process, we check that the output is what we expect.

# %%
# Test output
expected_parse_tree = "(\'<=\', \'temp_djf_iamean_s0p_hist\', -6.0)"
assert expected_parse_tree == output.get()[0]

for item in ['temp','djf','iamean','s0p','hist']:
    assert item in output.get()[1]
    
assert output.get()[2] == 'None'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-be71415d395e> in <module>
#       1 # Test output
#       2 expected_parse_tree = "(\'<=\', \'temp_djf_iamean_s0p_hist\', -6.0)"
# ----> 3 assert expected_parse_tree == output.get()[0]
#       4
#       5 for item in ['temp','djf','iamean','s0p','hist']:
#
# AssertionError:
